# %%
import os
import numpy as np
import pandas as pd

# %%
records = []

os.chdir("../result/")
for d in os.listdir("./"):
    if os.path.isdir(d):
        os.chdir(d)
        for f in os.listdir("./"):
            
            if f.endswith("_result.tsv"):
                df = pd.read_table(f)

                records_single = []
                for filter_params, df_filter in df.groupby(['filter_by_graph', 'filter_by_cys_pair', 'prob_threshold', 'node_num_threshold']):
                    avg_f1 = np.average(df_filter['f1'])
                    std_f1 = np.std(df_filter['f1'], ddof=1)
                    filter_by_graph, filter_by_cys_pair, prob_threshold, node_num_threshold = filter_params
                    records_single.append({
                        "filter_by_graph": filter_by_graph,
                        "filter_by_cys_pair": filter_by_cys_pair,
                        "prob_threshold": prob_threshold,
                        "node_num_threshold": node_num_threshold,
                        "f1_avg": round(avg_f1, 6),
                        "f1_std": round(std_f1, 6),
                    })
                df_single = pd.DataFrame(records_single)
                target_row = df_single.iloc[df_single['f1_avg'].argmax()]

                record = {"file": f}
                record.update(dict(target_row))
                records.append(record)
        os.chdir("..")
        
os.chdir("../analysis/")

# %%
pd.DataFrame(records).sort_values(by=['f1_avg'])
# Out:
#                                     file  filter_by_graph  filter_by_cys_pair  \
# 14       af2_pair_repr_rank_3_result.tsv             True               False
# 21       af2_pair_repr_rank_4_result.tsv             True               False
# 26      af2_pair_repr_model_4_result.tsv             True               False
# 38       af2_pair_repr_rank_5_result.tsv             True               False
# 17      af2_pair_repr_model_3_result.tsv             True               False
# 25      af2_pair_repr_model_5_result.tsv             True               False
# 45   af2_resi_repr_rank_4_max_result.tsv             True               False
# 10   af2_resi_repr_rank_5_max_result.tsv             True               False
# 4    af2_resi_repr_rank_3_max_result.tsv             True               False
# 47                     nb_max_result.tsv             True               False
# 44   af2_resi_repr_rank_4_avg_result.tsv             True               False
# 37   af2_resi_repr_rank_4_cat_result.tsv             True               False
# 11   af2_resi_repr_rank_5_avg_result.tsv             True               False
# 35  af2_resi_repr_model_3_max_result.tsv             True               False
# 16   af2_resi_repr_rank_5_cat_result.tsv             True               False
# 15  af2_resi_repr_model_5_max_result.tsv             True               False
# 19   af2_resi_repr_rank_3_avg_result.tsv             True               False
# 8   af2_resi_repr_model_4_max_result.tsv             True               False
# 18   af2_resi_repr_rank_3_cat_result.tsv             True               False
# 20  af2_resi_repr_model_3_avg_result.tsv             True               False
# 3   af2_resi_repr_model_5_avg_result.tsv             True               False
# 24  af2_resi_repr_model_5_cat_result.tsv             True               False
# 2   af2_resi_repr_model_4_avg_result.tsv             True               False
# 5   af2_resi_repr_model_3_cat_result.tsv             True               False
# 23  af2_resi_repr_model_4_cat_result.tsv             True               False
# 36                     nb_avg_result.tsv             True               False
# 39               freq_mtx_uni_result.tsv             True                True
# 0                      nb_cat_result.tsv             True               False
# 13                nb_centroid_result.tsv             True               False
# 30   af2_resi_repr_rank_2_max_result.tsv             True               False
# 9   af2_resi_repr_model_1_max_result.tsv             True               False
# 41   af2_resi_repr_rank_1_max_result.tsv             True               False
# 29  af2_resi_repr_model_2_max_result.tsv             True               False
# 28  af2_resi_repr_model_1_avg_result.tsv             True               False
# 6    af2_resi_repr_rank_2_cat_result.tsv             True               False
# 33   af2_resi_repr_rank_1_avg_result.tsv             True               False
# 7    af2_resi_repr_rank_2_avg_result.tsv             True               False
# 31   af2_resi_repr_rank_1_cat_result.tsv             True               False
# 42  af2_resi_repr_model_2_avg_result.tsv             True               False
# 32  af2_resi_repr_model_1_cat_result.tsv             True               False
# 1   af2_resi_repr_model_2_cat_result.tsv             True               False
# 43       af2_pair_repr_rank_2_result.tsv             True                True
# 27      af2_pair_repr_model_1_result.tsv             True                True
# 40       af2_pair_repr_rank_1_result.tsv             True               False
# 46      af2_pair_repr_model_2_result.tsv             True               False
# 12                   esm2_max_result.tsv             True               False
# 34                   esm2_cat_result.tsv             True               False
# 22                   esm2_avg_result.tsv             True               False
#
#     prob_threshold  node_num_threshold    f1_avg    f1_std
# 14             0.4                   0  0.604204  0.002559
# 21             0.5                   0  0.605078  0.002014
# 26             0.5                   0  0.605239  0.002899
# 38             0.5                   0  0.607620  0.002871
# 17             0.5                   0  0.611509  0.001459
# 25             0.5                   0  0.615027  0.002628
# 45             0.4                   0  0.632343  0.001006
# 10             0.4                   0  0.634708  0.001148
# 4              0.4                   0  0.636111  0.001939
# 47             0.6                   1  0.636301  0.000211
# 44             0.4                   0  0.637590  0.001953
# 37             0.4                   0  0.639936  0.001292
# 11             0.4                   0  0.640023  0.001302
# 35             0.4                   0  0.640193  0.001422
# 16             0.4                   0  0.640440  0.001653
# 15             0.4                   0  0.640879  0.001992
# 19             0.4                   0  0.642306  0.001288
# 8              0.4                   0  0.643046  0.000163
# 18             0.4                   0  0.644632  0.000852
# 20             0.4                   0  0.645752  0.001030
# 3              0.4                   0  0.646141  0.001373
# 24             0.4                   0  0.646877  0.002468
# 2              0.5                   0  0.648119  0.001652
# 5              0.4                   0  0.648434  0.002810
# 23             0.4                   0  0.651422  0.001244
# 36             0.6                   2  0.662135  0.001561
# 39             0.7                   2  0.665467  0.002905
# 0              0.6                   2  0.666417  0.000905
# 13             0.6                   2  0.670420  0.000314
# 30             0.7                   2  0.728083  0.001358
# 9              0.7                   2  0.728232  0.003766
# 41             0.7                   2  0.729042  0.001481
# 29             0.7                   2  0.731158  0.001103
# 28             0.7                   3  0.734728  0.000327
# 6              0.7                   3  0.735141  0.004124
# 33             0.7                   2  0.735527  0.001878
# 7              0.7                   2  0.735672  0.003214
# 31             0.7                   3  0.735953  0.001462
# 42             0.7                   2  0.736989  0.001883
# 32             0.7                   3  0.737012  0.002452
# 1              0.7                   2  0.737649  0.001111
# 43             0.8                   2  0.739637  0.001936
# 27             0.8                   2  0.740347  0.003357
# 40             0.7                   1  0.741652  0.001420
# 46             0.7                   1  0.741779  0.001235
# 12             0.8                   3  0.751765  0.001049
# 34             0.8                   3  0.753326  0.000791
# 22             0.8                   4  0.753731  0.001226
